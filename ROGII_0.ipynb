# %%
import kagglehub

# Download latest version
path = kagglehub.competition_download('rogii-wellbore-geology-prediction')

print("Path to competition files:", path)
# Out:
# Downloading to C:\Users\31118\.cache\kagglehub\competitions\rogii-wellbore-geology-prediction.archive...
# 100%|██████████| 779M/779M [04:04<00:00, 3.34MB/s]
# Extracting files...
# Path to competition files: C:\Users\31118\.cache\kagglehub\competitions\rogii-wellbore-geology-prediction
